# %%
import psycopg2
import sqlalchemy as sql
import pandas as pd

# %%
#retrieve data from database
engine=sql.create_engine('postgresql://postgres:password@database-1.ccsn2yvevp9q.us-west-2.rds.amazonaws.com)
# Out:
#   File "/var/folders/y8/z25h4y997psc483tj59t6x_w0000gn/T/ipykernel_15601/2045555090.py", line 2
#     engine=sql.create_engine('postgresql://postgres:password@database-1.ccsn2yvevp9q.us-west-2.rds.amazonaws.com)
#                                                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
#get table names
engine
# Out:
# Engine(postgresql://postgres:***@hue-db.ccsn2yvevp9q.us-west-2.rds.amazonaws.com)

# %%
#read in csv file 
df=pd.read_csv('updated HUE df.csv')
df
# Out:
#                     Organization Name  \
# 0                   Health In Her HUE
# 1                           Satvacart
# 2                              Sococo
# 3                       Project Vesta
# 4    Weather Risk Management Services
# ..                                ...
# 995      Liberty Tripadvisor Holdings
# 996              Nivalis Therapeutics
# 997                  Hartmann Capital
# 998                            Archer
# 999                          Kr Space
#
#                                             Industries  \
# 0                       Health Care, Wellness, Women's
# 1    Consumer Goods, E-Commerce, Food Delivery, Gro...
# 2               Collaboration, SaaS, Virtual Workforce
# 3    Energy Storage, Environmental Consulting, Rene...
# 4                         Agriculture, AgTech, Farming
# ..                                                 ...
# 995                                    Leisure, Travel
# ...
