# %%
import pandas as pd

df=pd.read_csv("companies-12-11-2022.csv",sep=",")
df
# Out:
#                     Organization Name  \
# 0                   Health In Her HUE
# 1                           Satvacart
# 2                              Sococo
# 3                       Project Vesta
# 4    Weather Risk Management Services
# ..                                ...
# 995      Liberty Tripadvisor Holdings
# 996              Nivalis Therapeutics
# 997                  Hartmann Capital
# 998                            Archer
# 999                          Kr Space
#
#                                  Organization Name URL  \
# 0    https://www.crunchbase.com/organization/health...
# 1    https://www.crunchbase.com/organization/satvacart
# 2       https://www.crunchbase.com/organization/sococo
# 3    https://www.crunchbase.com/organization/projec...
# 4    https://www.crunchbase.com/organization/weathe...
# ..                                                 ...
# 995  https://www.crunchbase.com/organization/libert...
# ...

# %%
df['CB Rank (Company)'] = df['CB Rank (Company)'].replace(to_replace = "," , value = "", regex=True)
print(df['CB Rank (Company)'])
# Out:
# 0      29852
# 1      29853
# 2      29854
# 3      29855
# 4      29856
#        ...
# 995    30847
# 996    30848
# 997    30849
# 998    30850
# 999    30851
# Name: CB Rank (Company), Length: 1000, dtype: object

# %%
df
# Out:
#                     Organization Name  \
# 0                   Health In Her HUE
# 1                           Satvacart
# 2                              Sococo
# 3                       Project Vesta
# 4    Weather Risk Management Services
# ..                                ...
# 995      Liberty Tripadvisor Holdings
# 996              Nivalis Therapeutics
# 997                  Hartmann Capital
# 998                            Archer
# 999                          Kr Space
#
#                                  Organization Name URL  \
# 0    https://www.crunchbase.com/organization/health...
# 1    https://www.crunchbase.com/organization/satvacart
# 2       https://www.crunchbase.com/organization/sococo
# 3    https://www.crunchbase.com/organization/projec...
# 4    https://www.crunchbase.com/organization/weathe...
# ..                                                 ...
# 995  https://www.crunchbase.com/organization/libert...
# ...

# %%
df.drop(df.columns[[1]], axis = 1, inplace = True)

# %%
df
# Out:
#                     Organization Name  \
# 0                   Health In Her HUE
# 1                           Satvacart
# 2                              Sococo
# 3                       Project Vesta
# 4    Weather Risk Management Services
# ..                                ...
# 995      Liberty Tripadvisor Holdings
# 996              Nivalis Therapeutics
# 997                  Hartmann Capital
# 998                            Archer
# 999                          Kr Space
#
#                                             Industries  \
# 0                       Health Care, Wellness, Women's
# 1    Consumer Goods, E-Commerce, Food Delivery, Gro...
# 2               Collaboration, SaaS, Virtual Workforce
# 3    Energy Storage, Environmental Consulting, Rene...
# 4                         Agriculture, AgTech, Farming
# ..                                                 ...
# 995                                    Leisure, Travel
# ...

# %%
#Export this cleaned up df as a new csv
df.to_csv(r'C:\Users\Desktop\HUE_Sample_Project\companies-12-11-2022.csv', index=False, header=True)
print(df)
# Out:
#                     Organization Name  \
# 0                   Health In Her HUE
# 1                           Satvacart
# 2                              Sococo
# 3                       Project Vesta
# 4    Weather Risk Management Services
# ..                                ...
# 995      Liberty Tripadvisor Holdings
# 996              Nivalis Therapeutics
# 997                  Hartmann Capital
# 998                            Archer
# 999                          Kr Space
#
#                                             Industries  \
# 0                       Health Care, Wellness, Women's
# 1    Consumer Goods, E-Commerce, Food Delivery, Gro...
# 2               Collaboration, SaaS, Virtual Workforce
# 3    Energy Storage, Environmental Consulting, Rene...
# 4                         Agriculture, AgTech, Farming
# ..                                                 ...
# 995                                    Leisure, Travel
# ...
